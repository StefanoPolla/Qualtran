# %%
import qualtran as qt
from qualtran.bloqs.basic_gates import Toffoli, CSwap, TwoBitCSwap
from qualtran.bloqs.mcmt import And
from qualtran import drawing

# %%
drawing.show_bloq(TwoBitCSwap().decompose_bloq())

# %%
drawing.draw_musical_score(
    drawing.get_musical_score_data(TwoBitCSwap().decompose_bloq())
)
# Out:
# (<Figure size 1000x175 with 1 Axes>, <Axes: >)
